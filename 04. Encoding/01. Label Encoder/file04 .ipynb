# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
df=pd.DataFrame(data={
    "shape": ["circle","square","triangle","circle","square","triangle","triangle","circle","square","circle"],
    "area" : [28.3, 36.0, 45.0, 78.6, 25.0, 45.4, 74.6, 23.0, 45.6, 40.5],
    "price": [99, 199, 299, 399, 499, 599, 699, 799, 899, 999],
    "target": ["class1","class2","class1","class2","class1","class2","class1","class2","class1","class2"]
})
df
# Out:
#       shape  area  price  target
# 0    circle  28.3     99  class1
# 1    square  36.0    199  class2
# 2  triangle  45.0    299  class1
# 3    circle  78.6    399  class2
# 4    square  25.0    499  class1
# 5  triangle  45.4    599  class2
# 6  triangle  74.6    699  class1
# 7    circle  23.0    799  class2
# 8    square  45.6    899  class1
# 9    circle  40.5    999  class2

# %%
x=df.drop(columns='target')
y= df['target']

# %%
xtrain,xtest,ytrain,ytest= train_test_split(x,y,train_size=0.8, random_state=42)

# %%
xtrain
# Out:
#       shape  area  price
# 5  triangle  45.4    599
# 0    circle  28.3     99
# 7    circle  23.0    799
# 2  triangle  45.0    299
# 9    circle  40.5    999
# 4    square  25.0    499
# 3    circle  78.6    399
# 6  triangle  74.6    699

# %%
encoder=LabelEncoder()

# %%
# encoder.fit_transform(xtrain)      # ValueError: y should be a 1d array, got an array of shape (8, 3) instead.

# %%
encoder.fit_transform(xtrain['shape'])
# Out:
# array([2, 0, 0, 2, 0, 1, 0, 2])

# %%
encoder.transform(xtest['shape'])
# Out:
# array([1, 1])

# %% [markdown]
# ***Scenario-2***

# %%
encoder.transform(['triangle'])
# Out:
# array([2])

# %% [markdown]
# ***Scenario-3***

# %%
encoder.transform(['cone'])          # ValueError: y contains previously unseen labels: 'cone'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\_encode.py:229, in _encode(values, uniques, check_unknown)
#     228 try:
# --> 229     return _map_to_integer(values, uniques)
#     230 except KeyError as e:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\_encode.py:168, in _map_to_integer(values, uniques)
#     167 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 168 return xp.asarray([table[v] for v in values], device=device(values))
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\_encode.py:161, in _nandict.__missing__(self, key)
#     160     return self.nan_value
# --> 161 raise KeyError(key)
#
# KeyError: 'cone'
#
# During handling of the above exception, another exception occurred:
#
# ...
