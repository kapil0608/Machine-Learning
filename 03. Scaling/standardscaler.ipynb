# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Upload Data

# %%
df=pd.read_csv('standardscaler_.csv')
df
# Out:
#      Experience_Years    Age  Education_Level  Hours_Per_Week     Salary
# 0                5.99  34.63                3           41.12   87638.54
# 1                4.72  39.55                4           46.82   84956.80
# 2                6.30  23.01                1           40.63   73501.52
# 3                8.05  32.81                4           37.85  100707.27
# 4                4.53  26.75                3           40.61   80094.46
# ..                ...    ...              ...             ...        ...
# 495              6.08  28.59                4           33.27   67897.46
# 496              2.93  38.99                4           40.63   76200.98
# 497              4.62  33.20                4           49.69   72773.89
# 498              3.25  27.14                4           35.00   76373.15
# 499              2.23  32.86                2           36.61   58804.58
#
# [500 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience_Years  500 non-null    float64
#  1   Age               500 non-null    float64
#  2   Education_Level   500 non-null    int64
#  3   Hours_Per_Week    500 non-null    float64
#  4   Salary            500 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 19.7 KB

# %%
df.corr()
# Out:
#                   Experience_Years       Age  Education_Level  Hours_Per_Week  \
# Experience_Years          1.000000 -0.073255        -0.071472        0.060724
# Age                      -0.073255  1.000000        -0.004516        0.047329
# Education_Level          -0.071472 -0.004516         1.000000        0.006592
# Hours_Per_Week            0.060724  0.047329         0.006592        1.000000
# Salary                    0.514034 -0.010178         0.323822        0.083765
#
#                     Salary
# Experience_Years  0.514034
# Age              -0.010178
# Education_Level   0.323822
# Hours_Per_Week    0.083765
# Salary            1.000000

# %% [markdown]
# ### Defining x and y

# %%
x=df.drop(columns='Salary')
y=df['Salary']

# %% [markdown]
# ### Train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
sns.boxplot(x)
# Out:
# <Axes: >

# %% [markdown]
# ### StandardScaler Preprocessing Technique

# %%
scaling = StandardScaler()

xtrain_scaled=scaling.fit_transform(xtrain)
xtrain_scaled
# Out:
# array([[ 0.4101165 , -1.48786319, -1.33860046,  0.52585485],
#        [ 0.73171644, -2.31816681,  0.46119848, -0.90974838],
#        [-1.44291174,  0.77450449,  1.36109795,  0.21707985],
#        ...,
#        [-0.73845473, -0.68272029, -1.33860046, -1.06213085],
#        [ 0.07320227, -0.5401429 , -1.33860046,  0.97097205],
#        [-0.35559765,  0.89821134,  1.36109795, -0.7313005 ]],
#       shape=(400, 4))

# %%
xtest_scaled = scaling.transform(xtest)
xtest_scaled
# Out:
# array([[ 1.56379248, -1.60318314, -0.43870099, -0.33430407],
#        [ 1.59442105, -0.2445045 , -1.33860046,  0.54991524],
#        [ 2.19678285, -0.04950895, -1.33860046,  0.23312011],
#        [-0.73334996,  0.04903719, -1.33860046,  0.70029267],
#        [-0.16672149,  0.42015774,  1.36109795, -0.23605748],
#        [ 1.20135445,  1.43497327, -0.43870099,  0.37547741],
#        [ 0.18550701,  0.22096874, -1.33860046, -0.09771024],
#        [ 0.59388789,  1.65722626, -0.43870099, -0.1317958 ],
#        [ 0.36417365, -1.97430369, -0.43870099, -0.17390148],
#        [-0.06973104, -0.26756849, -1.33860046,  1.12936961],
#        [ 0.55304981, -0.88400602, -1.33860046, -0.7252854 ],
#        [ 0.17529749,  0.60886311, -0.43870099,  1.95744801],
#        [-1.09578799, -1.43963849, -0.43870099, -0.54483248],
#        [-0.83034042,  0.17693749, -1.33860046,  0.64816183],
#        [ 0.50710696, -0.8504584 , -0.43870099, -0.59295326],
# ...

# %%
scaling.mean_
# Out:
# array([ 5.0066  , 30.066125,  2.4875  , 40.307325])

# %%
scaling.var_
# Out:
# array([ 3.83750694, 22.74660123,  1.23484375, 24.87466209])

# %%
int(xtrain_scaled[:,1].mean())
# Out:
# 0

# %%
xtrain_scaled[:,1].std()
# Out:
# np.float64(0.9999999999999998)

# %%
xtrain_scaled[:,0].std()
# Out:
# np.float64(1.0)

# %% [markdown]
# ### RobustScaler Preprocessing Technique

# %%
robust_scaling = RobustScaler()

robust_scaling.fit_transform(xtrain)
# Out:
# array([[ 0.29064487, -1.13786253, -0.75      ,  0.39363242],
#        [ 0.5195277 , -1.76718315,  0.25      , -0.64254703],
#        [-1.02815622,  0.57687723,  0.75      ,  0.170767  ],
#        ...,
#        [-0.52679382, -0.52761224, -0.75      , -0.75253256],
#        [ 0.05086285, -0.41954708, -0.75      ,  0.71490593],
#        [-0.25431426,  0.67063965,  0.75      , -0.51374819]],
#       shape=(400, 4))

# %%
robust_scaling.transform(xtest)
# Out:
# array([[ 1.11171662, -1.22526818, -0.25      , -0.22720695],
#        [ 1.13351499, -0.1954708 , -0.75      ,  0.41099855],
#        [ 1.56221617, -0.0476758 , -0.75      ,  0.18234443],
#        [-0.52316076,  0.02701629, -0.75      ,  0.5195369 ],
#        [-0.11989101,  0.30830354,  0.75      , -0.15629522],
#        [ 0.8537693 ,  1.07747318, -0.25      ,  0.28509407],
#        [ 0.13079019,  0.15733015, -0.75      , -0.05643994],
#        [ 0.42143506,  1.24592769, -0.25      , -0.08104197],
#        [ 0.25794732, -1.50655542, -0.25      , -0.11143271],
#        [-0.05086285, -0.21295193, -0.75      ,  0.829233  ],
#        [ 0.39237057, -0.68017481, -0.75      , -0.50940666],
#        [ 0.12352407,  0.45133095, -0.25      ,  1.42691751],
#        [-0.78110808, -1.10131108, -0.25      , -0.37916064],
#        [-0.59218892,  0.12395709, -0.75      ,  0.48191027],
#        [ 0.35967302, -0.65474772, -0.25      , -0.41389291],
# ...

# %%
robust_scaling.center_
# Out:
# array([ 5.01, 30.13,  2.5 , 40.21])

# %% [markdown]
# ### MinMaxScaler Preprocessing Technique

# %%
MinMax_scaling= MinMaxScaler()
MinMax_scaling.fit_transform(xtrain)
# Out:
# array([[0.52060932, 0.19753577, 0.        , 0.5735775 ],
#        [0.57706093, 0.04014308, 0.66666667, 0.33943754],
#        [0.1953405 , 0.6263911 , 1.        , 0.52321779],
#        ...,
#        [0.31899642, 0.35015898, 0.        , 0.3145847 ],
#        [0.46146953, 0.37718601, 0.        , 0.64617397],
#        [0.38620072, 0.64984102, 1.        , 0.36854153]], shape=(400, 4))

# %%
MinMax_scaling.transform(xtest)
# Out:
# array([[0.72311828, 0.17567568, 0.33333333, 0.43328973],
#        [0.72849462, 0.43322734, 0.        , 0.57750164],
#        [0.83422939, 0.47019078, 0.        , 0.52583388],
#        [0.31989247, 0.48887122, 0.        , 0.60202747],
#        [0.41935484, 0.55922099, 1.        , 0.44931328],
#        [0.65949821, 0.75158983, 0.33333333, 0.54905167],
#        [0.4811828 , 0.52146264, 0.        , 0.47187704],
#        [0.55286738, 0.79372019, 0.33333333, 0.46631785],
#        [0.5125448 , 0.10532591, 0.33333333, 0.45945062],
#        [0.43637993, 0.42885533, 0.        , 0.67200785],
#        [0.54569892, 0.31200318, 0.        , 0.36952256],
#        [0.47939068, 0.59499205, 0.33333333, 0.80706344],
#        [0.2562724 , 0.20667727, 0.33333333, 0.39895356],
#        [0.30286738, 0.51311606, 0.        , 0.59352518],
#        [0.53763441, 0.31836248, 0.33333333, 0.3911053 ],
#        [0.61827957, 0.59419714, 0.        , 0.50654022],
# ...
